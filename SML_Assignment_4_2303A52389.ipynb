# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishwateja-123/SML_2303A52389_B44/blob/main/SML_Assignment_4_2303A52389.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
y=df['price_range']
print(y)
print(y.shape)
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64
# (2000,)

# %%
z=df[:1]
print(z)
print(z.shape)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
#
# [1 rows x 21 columns]
# (1, 21)

# %%
x=df.drop('price_range',axis=1)
print(x)
print(x.shape)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Normalization of the data
#Features
ddf=(x-x.min())/(x.max()-x.min())
ddf
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789   0.0         0.68       0.0  0.052632     0.0
# 1          0.347361   1.0         0.00       1.0  0.000000     1.0
# 2          0.041416   1.0         0.00       1.0  0.105263     1.0
# 3          0.076152   1.0         0.80       0.0  0.000000     0.0
# 4          0.881764   1.0         0.28       0.0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  0.10   0.010204  0.170895
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(xx,y,test_size=0.2,random_state=20)

# %%
x_train
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 1500       0.483634   0.0         0.08       1.0  0.315789     0.0
# 451        0.314629   1.0         0.48       0.0  0.000000     1.0
# 1627       0.243153   0.0         0.96       0.0  0.263158     0.0
# 669        0.148297   0.0         0.00       0.0  0.000000     1.0
# 1567       0.293253   0.0         0.96       0.0  0.000000     0.0
# ...             ...   ...          ...       ...       ...     ...
# 924        0.978624   0.0         0.12       1.0  0.789474     1.0
# 1247       0.711423   1.0         0.00       1.0  0.000000     0.0
# 271        0.152973   0.0         0.64       1.0  0.000000     1.0
# 474        0.979960   0.0         0.16       0.0  0.000000     0.0
# 1379       0.180361   0.0         0.96       0.0  0.105263     0.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 1500    0.935484  0.000000   0.225000  0.142857  0.75   0.005102  0.712283
# ...

# %%
x_test
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 1556       0.249833   1.0         0.36       1.0  0.052632     1.0
# 1560       0.915832   0.0         0.00       0.0  0.263158     1.0
# 1559       0.113560   0.0         0.96       0.0  0.368421     1.0
# 1594       0.056780   1.0         0.04       0.0  0.842105     1.0
# 906        0.989980   1.0         0.28       1.0  0.315789     1.0
# ...             ...   ...          ...       ...       ...     ...
# 959        0.713427   0.0         0.00       1.0  0.157895     0.0
# 1939       0.726119   1.0         0.80       0.0  0.631579     1.0
# 668        0.785571   0.0         0.52       1.0  0.210526     0.0
# 534        0.771543   1.0         0.44       1.0  0.000000     0.0
# 1111       0.824315   1.0         0.56       1.0  0.000000     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 1556    0.661290  0.555556   0.200000  1.000000  0.15   0.460204  0.313084
# ...

# %%
y_train
# Out:
# 1500    2
# 451     1
# 1627    3
# 669     1
# 1567    1
#        ..
# 924     2
# 1247    1
# 271     0
# 474     2
# 1379    1
# Name: price_range, Length: 1600, dtype: int64

# %%
y_test
# Out:
# 1556    3
# 1560    2
# 1559    2
# 1594    1
# 906     3
#        ..
# 959     3
# 1939    2
# 668     3
# 534     2
# 1111    3
# Name: price_range, Length: 400, dtype: int64

# %%
#Question-2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d1=pd.read_csv('/content/housing.csv')
d1=d1.fillna(0)
d1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y1=d1['median_house_value']
print(y1)
print(y1.shape)
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64
# (20640,)

# %%
x1=d1.drop('median_house_value',axis=1)
print(x1)
print(x1.shape)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
d1.shape
# Out:
# (20640, 10)

# %%
print(d1['longitude'].shape)
print(d1['latitude'].shape)
print(d1['housing_median_age'].shape)
print(d1['total_rooms'].shape)
print(d1['total_bedrooms'].shape)
print(d1['population'].shape)
print(d1['households'].shape)
print(d1['median_income'].shape)
# Out:
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)
# (20640,)

# %%
d1.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
ddg=(x1 - x1.min())/(x1.max() - x1.min())
ddg
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     219     try:
# --> 220         result = func(left, right)
#     221     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     241             # error: "None" not callable
# --> 242             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     130     if result is None:
# --> 131         result = _evaluate_standard(op, op_str, a, b)
#     132
#
# ...

# %%
print(xx2.shape)
print(y1.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-dc8e54c4a06d> in <cell line: 1>()
# ----> 1 print(xx2.shape)
#       2 print(y1.shape)
#
# NameError: name 'xx2' is not defined

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(xx2,y1,test_size=0.2,random_state=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-68eeaa5b24dd> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x1_train,x1_test,y1_train,y1_test=train_test_split(xx2,y1,test_size=0.2,random_state=50)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     212                     )
#     213                 ):
# --> 214                     return func(*args, **kwargs)
#     215             except InvalidParameterError as e:
#     216                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2644         raise ValueError("At least one array required as input")
#    2645
# ...

# %%
x1_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7728     -118.13     33.92                28.0       3069.0           864.0
# 14565    -117.20     32.84                32.0       2033.0           394.0
# 8099     -118.22     33.81                41.0        726.0           166.0
# 4772     -118.34     34.04                42.0       1681.0           360.0
# 11663    -118.02     33.85                31.0       1922.0           329.0
# ...          ...       ...                 ...          ...             ...
# 1607     -122.08     37.87                24.0       6130.0          1359.0
# 3915     -118.52     34.19                37.0       1560.0           275.0
# 14729    -117.02     32.80                31.0       2692.0           445.0
# 4367     -118.27     34.10                41.0       3729.0           740.0
# 15715    -122.45     37.79                46.0       2009.0           464.0
#
# ...

# %%
x_test
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 1556       0.249833   1.0         0.36       1.0  0.052632     1.0
# 1560       0.915832   0.0         0.00       0.0  0.263158     1.0
# 1559       0.113560   0.0         0.96       0.0  0.368421     1.0
# 1594       0.056780   1.0         0.04       0.0  0.842105     1.0
# 906        0.989980   1.0         0.28       1.0  0.315789     1.0
# ...             ...   ...          ...       ...       ...     ...
# 959        0.713427   0.0         0.00       1.0  0.157895     0.0
# 1939       0.726119   1.0         0.80       0.0  0.631579     1.0
# 668        0.785571   0.0         0.52       1.0  0.210526     0.0
# 534        0.771543   1.0         0.44       1.0  0.000000     0.0
# 1111       0.824315   1.0         0.56       1.0  0.000000     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 1556    0.661290  0.555556   0.200000  1.000000  0.15   0.460204  0.313084
# ...

# %%
y_train
# Out:
# 7728     177200.0
# 14565    181400.0
# 8099     156900.0
# 4772     171400.0
# 11663    213000.0
#            ...
# 1607     102700.0
# 3915     206900.0
# 14729    170000.0
# 4367     412700.0
# 15715    500001.0
# Name: median_house_value, Length: 16512, dtype: float64

# %%
y_test
# Out:
# 6111     117600.0
# 17742    292200.0
# 79       131300.0
# 13150    265900.0
# 527      210200.0
#            ...
# 16880    500001.0
# 2018      57800.0
# 3000     102900.0
# 18393    279500.0
# 11945    129300.0
# Name: median_house_value, Length: 4128, dtype: float64
